# %% [markdown]
# # Paris housing dataset

# %%
## Probelm statement

A distinguished group of investors seeks to establish a  real estate firm in the vibrant city of Paris. Recognizing the intricacies of the local market, they have engaged Mali Safi and Sons to analyze existing data, draw meaningful insights, and guide their strategic decisions. Mali safi and sons has decided to use regression models to understand how different variables affect the real estate market and identify trends that the business can take advantage of.
Objectives of Mali safi and sons

    a. In-Depth Data Analysis

    Conduct a thorough exploration of the dataset to understand the relationships between diverse variables and the prices
    of houses in the Parisian real estate market.

    b Regression Model Construction

    Develop regression models that  correlate property prices with key variables, including but not limited to square 
    meters, number of rooms, presence of amenities (yard, pool), city code, and other influential factors.

    c.Performance Evaluation

    Assess the efficiency of the regression model in identifying the factors that significantly impact property prices, 
    ensuring the model's reliability and predictive power.

    d.Visualization for Enhanced Understanding

    Create visually appealing and insightful representations of the regression findings, enabling the business investors to grasp complex relationships intuitively. This visualizations will serve as a powerful tool for communication and 
    decision-making.

    e.Strategic Guidance

    Derive strategic investment recommendations from the  analysis and regression findings. These recommendations will 
    empower the investors to navigate the Parisian real estate landscape with confidence, making informed and lucrative business decisions.

In order to achieve these objectives, Mali Safi and Sons aims to provide the investors group with a great understanding of the current market conditions in Paris and lay a good foundation for a successful real estate company in Paris.

# %%
import pandas as pd

df = pd.read_csv('ParisHousing.csv')

# %%
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...
